# %% [markdown]
# #**1. Palindrome**

# %%
def is_palindrome_number(number):
    # Convert the number to a string to easily reverse it
    num_str = str(number)
    # Reverse the string
    reversed_num_str = num_str[::-1]
    # Compare the original and reversed strings
    if num_str == reversed_num_str:
        return f"{number} is a palindrome number."
    else:
        return f"{number} is not a palindrome number."

# Example usage:
num1 = 121
print(is_palindrome_number(num1))

num2 = 12345
print(is_palindrome_number(num2))

num3 = 9009
print(is_palindrome_number(num3))

num4 = 0
print(is_palindrome_number(num4))
# Out:
# 121 is a palindrome number.
# 12345 is not a palindrome number.
# 9009 is a palindrome number.
# 0 is a palindrome number.

# %% [markdown]
# #**2. Odd or Even of the Number**

# %%
def check_odd_even(number):
    if number % 2 == 0:
        return f"{number} is an even number."
    else:
        return f"{number} is an odd number."

# Example usage:
num1 = 10
print(check_odd_even(num1))

num2 = 7
print(check_odd_even(num2))

num3 = 0
print(check_odd_even(num3))
# Out:
# 10 is an even number.
# 7 is an odd number.
# 0 is an even number.

# %% [markdown]
# #**3. Multiplication of Number**

# %%
def display_multiplication_table(number, limit=10):
    print(f"Multiplication Table for {number}:")
    for i in range(1, limit + 1):
        print(f"{number} x {i} = {number * i}")

# Example usage:
num = 7
display_multiplication_table(num)

print("\n") # Add a newline for better readability between examples

num = 12
display_multiplication_table(num, limit=5) # Displaying table up to 5 for 12
# Out:
# Multiplication Table for 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
#
# Multiplication Table for 12:
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60

# %% [markdown]
# #**4. Factorial of the Number**

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers"
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

# Example usage:
number = 5
print(f"The factorial of {number} is {factorial(number)}")

number = 0
print(f"The factorial of {number} is {factorial(number)}")

number = -3
print(f"The factorial of {number} is {factorial(number)}")
# Out:
# The factorial of 5 is 120
# The factorial of 0 is 1
# The factorial of -3 is Factorial is not defined for negative numbers

# %% [markdown]
# #**5. Expert System that provides simple decision-making.**

# %%
print("\n--- Testing Expert System Functionality ---")

# Test cases covering all temperature categories and sky conditions

# Hot category (temperature > 30)
print("\n--- Hot Weather Scenarios ---")
print(f"Hot & Sunny (35, 'Sunny'): {recommend_activity(35, 'Sunny')}")
print(f"Hot & Cloudy (32, 'Cloudy'): {recommend_activity(32, 'Cloudy')}")
print(f"Hot & Rainy (31, 'Rainy'): {recommend_activity(31, 'Rainy')}")

# Warm category (20 <= temperature <= 30)
print("\n--- Warm Weather Scenarios ---")
print(f"Warm & Sunny (25, 'Sunny'): {recommend_activity(25, 'Sunny')}")
print(f"Warm & Cloudy (22, 'Cloudy'): {recommend_activity(22, 'Cloudy')}")
print(f"Warm & Rainy (28, 'Rainy'): {recommend_activity(28, 'Rainy')}")
# Edge cases for Warm category boundaries
print(f"Warm Edge Case (20, 'Sunny'): {recommend_activity(20, 'Sunny')}")
print(f"Warm Edge Case (30, 'Cloudy'): {recommend_activity(30, 'Cloudy')}")

# Cool category (10 <= temperature < 20)
print("\n--- Cool Weather Scenarios ---")
print(f"Cool & Sunny (15, 'Sunny'): {recommend_activity(15, 'Sunny')}")
print(f"Cool & Cloudy (12, 'Cloudy'): {recommend_activity(12, 'Cloudy')}")
print(f"Cool & Rainy (18, 'Rainy'): {recommend_activity(18, 'Rainy')}")
# Edge cases for Cool category boundaries
print(f"Cool Edge Case (10, 'Cloudy'): {recommend_activity(10, 'Cloudy')}")
print(f"Cool Edge Case (19, 'Sunny'): {recommend_activity(19, 'Sunny')}")

# Cold category (temperature < 10)
print("\n--- Cold Weather Scenarios ---")
print(f"Cold & Sunny (5, 'Sunny'): {recommend_activity(5, 'Sunny')}")
print(f"Cold & Cloudy (8, 'Cloudy'): {recommend_activity(8, 'Cloudy')}")
print(f"Cold & Rainy (2, 'Rainy'): {recommend_activity(2, 'Rainy')}")

# Test with unrecognized sky condition
print("\n--- Unrecognized Sky Condition Scenarios ---")
print(f"Unrecognized Sky (25, 'windy'): {recommend_activity(25, 'windy')}")
print(f"Unrecognized Sky (15, 'snowy'): {recommend_activity(15, 'snowy')}")
print(f"Unrecognized Sky (5, 'foggy'): {recommend_activity(5, 'foggy')}")
# Out:
# --- Testing Expert System Functionality ---
#
# --- Hot Weather Scenarios ---
# Hot & Sunny (35, 'Sunny'): It's hot and sunny! Go swimming and enjoy the sun!
# Hot & Cloudy (32, 'Cloudy'): It's hot and cloudy. Relax indoors or find an air-conditioned spot.
# Hot & Rainy (31, 'Rainy'): It's hot and rainy. Stay hydrated indoors and avoid going out.
#
# --- Warm Weather Scenarios ---
# Warm & Sunny (25, 'Sunny'): It's warm and sunny! Go for a walk or have a picnic!
# Warm & Cloudy (22, 'Cloudy'): It's warm and cloudy. Visit a museum or art gallery.
# Warm & Rainy (28, 'Rainy'): It's warm and rainy. Read a book or watch a movie.
# Warm Edge Case (20, 'Sunny'): It's warm and sunny! Go for a walk or have a picnic!
# Warm Edge Case (30, 'Cloudy'): It's warm and cloudy. Visit a museum or art gallery.
#
# --- Cool Weather Scenarios ---
# Cool & Sunny (15, 'Sunny'): It's cool and sunny! Go hiking or cycling!
# Cool & Cloudy (12, 'Cloudy'): It's cool and cloudy. Enjoy a warm drink at a cafe.
# ...
